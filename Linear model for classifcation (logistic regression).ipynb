# %%
import pandas as pd 
import numpy as np
import warnings 
warnings.filterwarnings('ignore')
import datapipe_utils as dt

# %%
bd_train=pd.read_csv("/Users/lalitsachan/Dropbox/0.0 Data/bd_train.csv")

# %%
bd_test=pd.read_csv("/Users/lalitsachan/Dropbox/0.0 Data/bd_test.csv")

# %%
def children(children):
    
    child_num=children.str.replace('Zero','0')
    child_num=child_num.str.replace('4+','4',regex=False)
    child_num=pd.to_numeric(child_num,errors='coerce')
    
    return child_num

# %%
def age_band(age_band):
    
    ab_num=age_band.str.replace('71+','71-71',regex=False)
    k=ab_num.str.split('-',expand=True)
    
    for i in [0,1]:
        k.iloc[:,i]=pd.to_numeric(k.iloc[:,i],errors='coerce')
        
    ab_num=0.5*(k[0]+k[1])
    
    return ab_num

# %%
def family_income(family_income):
    
    fi_num=family_income.replace({'>=35,000':35,
                                  '<27,500, >=25,000':26.25,
                                  '<30,000, >=27,500':28.5,
                                  '<25,000, >=22,500':23.75,
                                  '<20,000, >=17,500':18.75,
                                  '<12,500, >=10,000':11.25,
                                  '<17,500, >=15,000':16.25,
                                  '<15,000, >=12,500':13.75,
                                  '<22,500, >=20,000':21.25,
                                  '<10,000, >= 8,000':9,
                                  '< 8,000, >= 4,000':6,
                                  '< 4,000':4})
    fi_num=pd.to_numeric(fi_num,errors='coerce')
    
    return fi_num

# %%
simple_numeric=[ 'year_last_moved',
'Average.Credit.Card.Transaction',
'Balance.Transfer',
'Term.Deposit',
'Life.Insurance',
'Medical.Insurance',
'Average.A.C.Balance',
'Personal.Loan',
'Investment.in.Mutual.Fund',
'Investment.Tax.Saving.Bond',
'Home.Loan',
'Online.Purchase.Amount',
'Investment.in.Commudity',
'Investment.in.Equity',
'Investment.in.Derivative',
'Portfolio.Balance']

cat_to_dummies=['status',
'occupation',
'occupation_partner',
'home_status',
'self_employed',
'self_employed_partner',
'TVarea',
'gender',
'region']

custom_var_dict={'children':children,'age_band':age_band,'family_income':family_income}

# %%
mypipe=dt.DataPipe(simple_numeric=simple_numeric,
                   cat_to_dummies=cat_to_dummies,
                  custom_var_dict=custom_var_dict)

# %%
mypipe.fit(bd_train)

# %%
x_train=mypipe.transform(bd_train)

# %%
x_train.shape
# Out:
# (8124, 71)

# %%
x_test=mypipe.transform(bd_test)

# %%
x_test.shape
# Out:
# (2031, 71)

# %%
bd_train
# Out:
#       REF_NO children age_band                status         occupation  \
# 0       4888     Zero    55-60               Widowed            Retired
# 1       8525     Zero    61-65               Partner            Retired
# 2       3411        3    31-35               Partner       Professional
# 3        692     Zero    51-55               Partner  Secretarial/Admin
# 4      10726        1    51-55               Partner            Retired
# ...      ...      ...      ...                   ...                ...
# 8119    2680        2    41-45  Single/Never Married          Housewife
# 8120    7564        2    41-45    Divorced/Separated       Professional
# 8121    9719        2    36-40               Partner  Secretarial/Admin
# 8122    9132     Zero    55-60               Partner          Housewife
# 8123    8547     Zero    55-60               Partner  Secretarial/Admin
#
#      occupation_partner home_status      family_income self_employed  \
# 0               Unknown    Own Home  <10,000, >= 8,000            No
# 1               Retired    Own Home           >=35,000            No
# 2             Housewife    Own Home  <25,000, >=22,500            No
# 3                 Other    Own Home  <20,000, >=17,500            No
# 4               Retired    Own Home           >=35,000            No
# ...                 ...         ...                ...           ...
# 8119       Professional    Own Home  <27,500, >=25,000            No
# 8120            Unknown    Own Home  <20,000, >=17,500            No
# 8121      Manual Worker    Own Home  <30,000, >=27,500            No
# 8122       Professional    Own Home  <30,000, >=27,500            No
# 8123            Retired    Own Home  <25,000, >=22,500            No
#
#      self_employed_partner  ...  Investment.Tax.Saving.Bond Home.Loan  \
# 0                       No  ...                       33.47     12.96
# 1                       No  ...                       45.96     28.95
# 2                       No  ...                        0.00      0.00
# 3                       No  ...                        0.00      0.00
# 4                       No  ...                        0.00      0.00
# ...                    ...  ...                         ...       ...
# 8119                    No  ...                       14.98      0.00
# 8120                    No  ...                       15.48      0.00
# 8121                    No  ...                        1.00      0.00
# 8122                    No  ...                        0.00      0.00
# 8123                    No  ...                        0.00      9.99
#
#      Online.Purchase.Amount Revenue.Grid  gender         region  \
# 0                      4.99            1  Female     North West
# 1                      3.99            2    Male     North West
# 2                      0.00            2  Female     North West
# 3                      0.00            2    Male     North West
# 4                      0.00            2  Female  West Midlands
# ...                     ...          ...     ...            ...
# 8119                 178.38            1  Female     South East
# 8120                  35.47            2  Female  East Midlands
# 8121                  15.47            2  Female     North West
# 8122                   0.00            2  Female     South East
# 8123                   0.00            2    Male     North West
#
#       Investment.in.Commudity  Investment.in.Equity  Investment.in.Derivative  \
# 0                       91.85                 25.71                     95.52
# 1                      127.65                 56.21                     89.20
# 2                        4.19                  0.00                      3.50
# 3                        9.59                  0.00                      7.99
# 4                       15.69                  5.83                     15.66
# ...                       ...                   ...                       ...
# 8119                    63.77                 79.58                     65.68
# 8120                    48.19                 27.81                     23.81
# 8121                    92.66                  3.41                     12.49
# 8122                    13.49                  0.00                     11.24
# 8123                     0.00                  6.66                      5.00
#
#       Portfolio.Balance
# 0                249.82
# 1                222.27
# 2                 17.05
# 3                -72.74
# 4                -13.98
# ...                 ...
# 8119             181.11
# 8120             104.01
# 8121             102.24
# 8122             -63.25
# 8123              18.44
#
# [8124 rows x 32 columns]

# %%
y_train=(bd_train['Revenue.Grid']==1).astype(int)

# %%
from sklearn.linear_model import LogisticRegression

# %%
params={'class_weight':['balanced',None],
       'penalty':['l1','l2'],
       'C':[.0001,.0005,.001,.005,.01,.05,.1,1,2,5,10]}

# %%
model=LogisticRegression(solver='liblinear')

# %%
from sklearn.model_selection import GridSearchCV

# %%
gs=GridSearchCV(model,
               param_grid=params,
               cv=10,
               scoring='roc_auc',
               n_jobs=-1,
               verbose=20
               )

# %%
gs.fit(x_train,y_train)
# Out:
# Fitting 10 folds for each of 44 candidates, totalling 440 fits
# GridSearchCV(cv=10, estimator=LogisticRegression(solver='liblinear'), n_jobs=-1,
#              param_grid={'C': [0.0001, 0.0005, 0.001, 0.005, 0.01, 0.05, 0.1, 1,
#                                2, 5, 10],
#                          'class_weight': ['balanced', None],
#                          'penalty': ['l1', 'l2']},
#              scoring='roc_auc', verbose=20)

# %%
gs.best_estimator_
# Out:
# LogisticRegression(C=0.05, class_weight='balanced', penalty='l1',
#                    solver='liblinear')

# %%
params={'class_weight':['balanced',None],
       'penalty':['l1','l2'],
       'C':[.01,.02,0.3,.04,0.05,0.06,0.07,0.08,0.09,0.1]}

# %%
gs=GridSearchCV(model,
               param_grid=params,
               cv=10,
               scoring='roc_auc',
               n_jobs=-1,
               verbose=20
               )

# %%
gs.fit(x_train,y_train)
# Out:
# Fitting 10 folds for each of 40 candidates, totalling 400 fits
# /Users/lalitsachan/anaconda3/lib/python3.10/site-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/lalitsachan/anaconda3/lib/python3.10/site-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# GridSearchCV(cv=10, estimator=LogisticRegression(solver='liblinear'), n_jobs=-1,
#              param_grid={'C': [0.01, 0.02, 0.3, 0.04, 0.05, 0.06, 0.07, 0.08,
#                                0.09, 0.1],
#                          'class_weight': ['balanced', None],
#                          'penalty': ['l1', 'l2']},
#              scoring='roc_auc', verbose=20)

# %%
gs.best_estimator_
# Out:
# LogisticRegression(C=0.06, class_weight='balanced', penalty='l1',
#                    solver='liblinear')

# %%
dt.report(gs.cv_results_,5)
# Out:
# Model with rank: 1
# Mean validation score: 0.955286 (std: 0.006627)
# Parameters: {'C': 0.06, 'class_weight': 'balanced', 'penalty': 'l1'}
#
# Model with rank: 2
# Mean validation score: 0.955272 (std: 0.006654)
# Parameters: {'C': 0.05, 'class_weight': 'balanced', 'penalty': 'l1'}
#
# Model with rank: 3
# Mean validation score: 0.955175 (std: 0.006753)
# Parameters: {'C': 0.04, 'class_weight': 'balanced', 'penalty': 'l1'}
#
# Model with rank: 4
# Mean validation score: 0.955166 (std: 0.006640)
# Parameters: {'C': 0.07, 'class_weight': 'balanced', 'penalty': 'l1'}
#
# Model with rank: 5
# Mean validation score: 0.955060 (std: 0.006660)
# Parameters: {'C': 0.08, 'class_weight': 'balanced', 'penalty': 'l1'}

# %%
logr=gs.best_estimator_

# %%
logr.fit(x_train,y_train)
# Out:
# LogisticRegression(C=0.06, class_weight='balanced', penalty='l1',
#                    solver='liblinear')

# %%
list(zip(x_train.columns,logr.coef_[0]))
# Out:
# [('status_Partner', 0.056096496441068226),
#  ('status_Single/Never Married', 0.0),
#  ('status_Divorced/Separated', 0.0),
#  ('status_Widowed', 0.0),
#  ('occupation_Professional', 0.0),
#  ('occupation_Retired', 0.0),
#  ('occupation_Secretarial/Admin', 0.0),
#  ('occupation_Housewife', 0.0),
#  ('occupation_Business Manager', 0.0),
#  ('occupation_Unknown', 0.0),
#  ('occupation_Manual Worker', 0.0),
#  ('occupation_Other', 0.0),
#  ('occupation_partner_Unknown', 0.0),
#  ('occupation_partner_Professional', 0.016575502248388774),
#  ('occupation_partner_Retired', 0.0),
#  ('occupation_partner_Manual Worker', 0.0),
#  ('occupation_partner_Business Manager', 0.0),
#  ('occupation_partner_Secretarial/Admin', 0.0),
#  ('occupation_partner_Housewife', 0.0),
#  ('occupation_partner_Other', 0.0),
#  ('home_status_Own Home', 0.0),
#  ('home_status_Rent from Council/HA', 0.0),
#  ('home_status_Rent Privately', 0.0),
#  ('home_status_Live in Parental Hom', 0.0),
#  ('self_employed_No', 0.0),
#  ('self_employed_partner_No', -0.25443495130954147),
#  ('TVarea_Central', 0.0),
#  ('TVarea_Carlton', 0.0),
#  ('TVarea_Meridian', -0.22907571083491485),
#  ('TVarea_Yorkshire', 0.0),
#  ('TVarea_Granada', 0.0),
#  ('TVarea_HTV', 0.0),
#  ('TVarea_Anglia', 0.0),
#  ('TVarea_Tyne Tees', 0.0),
#  ('TVarea_Scottish TV', 0.0),
#  ('TVarea_TV South West', 0.0),
#  ('TVarea_Grampian', 0.0),
#  ('TVarea_Unknown', 0.0),
#  ('TVarea_Ulster', 0.0),
#  ('gender_Female', -0.2505866945885903),
#  ('gender_Male', 0.0),
#  ('region_South East', 0.0),
#  ('region_North West', 0.0),
#  ('region_Unknown', 0.0),
#  ('region_South West', 0.0),
#  ('region_West Midlands', 0.0),
#  ('region_Scotland', 0.0),
#  ('region_East Midlands', 0.0),
#  ('region_North', 0.0),
#  ('region_Wales', 0.0),
#  ('region_East Anglia', 0.0),
#  ('region_Northern Ireland', 0.0),
#  ('year_last_moved', -0.0007149867612448297),
#  ('Average.Credit.Card.Transaction', 0.0227243337617555),
#  ('Balance.Transfer', -0.0052854388524972255),
#  ('Term.Deposit', -0.019699307169213254),
#  ('Life.Insurance', 0.01530952409181312),
#  ('Medical.Insurance', -0.006890520405796299),
#  ('Average.A.C.Balance', -0.0030141827533976305),
#  ('Personal.Loan', -0.029406519325884284),
#  ('Investment.in.Mutual.Fund', 0.0008620558263740018),
#  ('Investment.Tax.Saving.Bond', 0.09128065621099718),
#  ('Home.Loan', -0.07572531478150393),
#  ('Online.Purchase.Amount', 0.054154436612053956),
#  ('Investment.in.Commudity', 0.0),
#  ('Investment.in.Equity', 0.0),
#  ('Investment.in.Derivative', 0.0),
#  ('Portfolio.Balance', -0.00032220923169808406),
#  ('children', 0.0),
#  ('age_band', -0.013262586779693645),
#  ('family_income', -0.008374767729542347)]

# %%
(logr.coef_[0]==0).sum()
# Out:
# 51

# %%
# dont use l1 penalty with linearl models as form of feature selection , because that is strictly in the context
# of linear releationship . features might hold more predictive power if we consider non-linear relationship
# Out:
# [CV 2/10; 1/44] START C=0.0001, class_weight=balanced, penalty=l1...............
# [CV 2/10; 1/44] END C=0.0001, class_weight=balanced, penalty=l1;, score=0.946 total time=   0.0s
# [CV 10/10; 1/44] START C=0.0001, class_weight=balanced, penalty=l1..............
# [CV 10/10; 1/44] END C=0.0001, class_weight=balanced, penalty=l1;, score=0.939 total time=   0.0s
# [CV 4/10; 2/44] START C=0.0001, class_weight=balanced, penalty=l2...............
# [CV 4/10; 2/44] END C=0.0001, class_weight=balanced, penalty=l2;, score=0.961 total time=   0.1s
# [CV 8/10; 2/44] START C=0.0001, class_weight=balanced, penalty=l2...............
# [CV 8/10; 2/44] END C=0.0001, class_weight=balanced, penalty=l2;, score=0.954 total time=   0.1s
# [CV 5/10; 3/44] START C=0.0001, class_weight=None, penalty=l1...................
# [CV 5/10; 3/44] END C=0.0001, class_weight=None, penalty=l1;, score=0.893 total time=   0.0s
# [CV 1/10; 4/44] START C=0.0001, class_weight=None, penalty=l2...................
# [CV 1/10; 4/44] END C=0.0001, class_weight=None, penalty=l2;, score=0.946 total time=   0.0s
# [CV 9/10; 4/44] START C=0.0001, class_weight=None, penalty=l2...................
# [CV 9/10; 4/44] END C=0.0001, class_weight=None, penalty=l2;, score=0.964 total time=   0.1s
# [CV 3/10; 7/44] START C=0.0005, class_weight=None, penalty=l1...................
# [CV 3/10; 7/44] END C=0.0005, class_weight=None, penalty=l1;, score=0.950 total time=   0.1s
# [CV 4/10; 7/44] START C=0.0005, class_weight=None, penalty=l1...................
# [CV 4/10; 7/44] END C=0.0005, class_weight=None, penalty=l1;, score=0.950 total time=   0.0s
# [CV 9/10; 8/44] START C=0.0005, class_weight=None, penalty=l2...................
# [CV 9/10; 8/44] END C=0.0005, class_weight=None, penalty=l2;, score=0.964 total time=   0.1s
# [CV 10/10; 8/44] START C=0.0005, class_weight=None, penalty=l2..................
# [CV 10/10; 8/44] END C=0.0005, class_weight=None, penalty=l2;, score=0.936 total time=   0.0s
# [CV 5/10; 11/44] START C=0.001, class_weight=None, penalty=l1...................
# [CV 5/10; 11/44] END C=0.001, class_weight=None, penalty=l1;, score=0.942 total time=   0.0s
# [CV 6/10; 11/44] START C=0.001, class_weight=None, penalty=l1...................
# [CV 6/10; 11/44] END C=0.001, class_weight=None, penalty=l1;, score=0.918 total time=   0.0s
# [CV 7/10; 11/44] START C=0.001, class_weight=None, penalty=l1...................
# [CV 7/10; 11/44] END C=0.001, class_weight=None, penalty=l1;, score=0.952 total time=   0.0s
# [CV 8/10; 11/44] START C=0.001, class_weight=None, penalty=l1...................
# [CV 8/10; 11/44] END C=0.001, class_weight=None, penalty=l1;, score=0.938 total time=   0.0s
# [CV 9/10; 13/44] START C=0.005, class_weight=balanced, penalty=l1...............
# [CV 9/10; 13/44] END C=0.005, class_weight=balanced, penalty=l1;, score=0.963 total time=   0.1s
# [CV 10/10; 13/44] START C=0.005, class_weight=balanced, penalty=l1..............
# [CV 10/10; 13/44] END C=0.005, class_weight=balanced, penalty=l1;, score=0.956 total time=   0.1s
# [CV 1/10; 14/44] START C=0.005, class_weight=balanced, penalty=l2...............
# [CV 1/10; 14/44] END C=0.005, class_weight=balanced, penalty=l2;, score=0.958 total time=   0.1s
# [CV 2/10; 14/44] START C=0.005, class_weight=balanced, penalty=l2...............
# [CV 2/10; 14/44] END C=0.005, class_weight=balanced, penalty=l2;, score=0.947 total time=   0.1s
# [CV 1/10; 17/44] START C=0.01, class_weight=balanced, penalty=l1................
# [CV 1/10; 17/44] END C=0.01, class_weight=balanced, penalty=l1;, score=0.958 total time=   0.1s
# [CV 2/10; 17/44] START C=0.01, class_weight=balanced, penalty=l1................
# [CV 2/10; 17/44] END C=0.01, class_weight=balanced, penalty=l1;, score=0.949 total time=   0.1s
# [CV 3/10; 17/44] START C=0.01, class_weight=balanced, penalty=l1................
# [CV 3/10; 17/44] END C=0.01, class_weight=balanced, penalty=l1;, score=0.955 total time=   0.1s
# [CV 4/10; 17/44] START C=0.01, class_weight=balanced, penalty=l1................
# [CV 4/10; 17/44] END C=0.01, class_weight=balanced, penalty=l1;, score=0.962 total time=   0.1s
# [CV 7/10; 20/44] START C=0.01, class_weight=None, penalty=l2....................
# [CV 7/10; 20/44] END C=0.01, class_weight=None, penalty=l2;, score=0.950 total time=   0.1s
# [CV 8/10; 20/44] START C=0.01, class_weight=None, penalty=l2....................
# [CV 8/10; 20/44] END C=0.01, class_weight=None, penalty=l2;, score=0.934 total time=   0.1s
# [CV 9/10; 20/44] START C=0.01, class_weight=None, penalty=l2....................
# [CV 9/10; 20/44] END C=0.01, class_weight=None, penalty=l2;, score=0.964 total time=   0.1s
# [CV 10/10; 20/44] START C=0.01, class_weight=None, penalty=l2...................
# [CV 10/10; 20/44] END C=0.01, class_weight=None, penalty=l2;, score=0.937 total time=   0.1s
# [CV 5/10; 23/44] START C=0.05, class_weight=None, penalty=l1....................
# [CV 5/10; 23/44] END C=0.05, class_weight=None, penalty=l1;, score=0.942 total time=   0.1s
# [CV 6/10; 23/44] START C=0.05, class_weight=None, penalty=l1....................
# [CV 6/10; 23/44] END C=0.05, class_weight=None, penalty=l1;, score=0.924 total time=   0.1s
# [CV 7/10; 23/44] START C=0.05, class_weight=None, penalty=l1....................
# [CV 7/10; 23/44] END C=0.05, class_weight=None, penalty=l1;, score=0.949 total time=   0.3s
# [CV 8/10; 23/44] START C=0.05, class_weight=None, penalty=l1....................
# [CV 8/10; 23/44] END C=0.05, class_weight=None, penalty=l1;, score=0.934 total time=   0.1s
# [CV 9/10; 25/44] START C=0.1, class_weight=balanced, penalty=l1.................
# [CV 9/10; 25/44] END C=0.1, class_weight=balanced, penalty=l1;, score=0.964 total time=   0.7s
# [CV 10/10; 25/44] START C=0.1, class_weight=balanced, penalty=l1................
# [CV 10/10; 25/44] END C=0.1, class_weight=balanced, penalty=l1;, score=0.955 total time=   0.9s
# [CV 1/10; 26/44] START C=0.1, class_weight=balanced, penalty=l2.................
# [CV 1/10; 26/44] END C=0.1, class_weight=balanced, penalty=l2;, score=0.957 total time=   0.2s
# [CV 2/10; 26/44] START C=0.1, class_weight=balanced, penalty=l2.................
# [CV 2/10; 26/44] END C=0.1, class_weight=balanced, penalty=l2;, score=0.945 total time=   0.2s
# [CV 1/10; 31/44] START C=1, class_weight=None, penalty=l1.......................
# [CV 1/10; 31/44] END C=1, class_weight=None, penalty=l1;, score=0.951 total time=   0.3s
# [CV 2/10; 31/44] START C=1, class_weight=None, penalty=l1.......................
# [CV 2/10; 31/44] END C=1, class_weight=None, penalty=l1;, score=0.940 total time=   0.5s
# [CV 3/10; 31/44] START C=1, class_weight=None, penalty=l1.......................
# [CV 3/10; 31/44] END C=1, class_weight=None, penalty=l1;, score=0.944 total time=   0.5s
# [CV 4/10; 31/44] START C=1, class_weight=None, penalty=l1.......................
# [CV 4/10; 31/44] END C=1, class_weight=None, penalty=l1;, score=0.959 total time=   0.6s
# [CV 3/10; 34/44] START C=2, class_weight=balanced, penalty=l2...................
# [CV 3/10; 34/44] END C=2, class_weight=balanced, penalty=l2;, score=0.949 total time=   0.3s
# [CV 4/10; 34/44] START C=2, class_weight=balanced, penalty=l2...................
# [CV 4/10; 34/44] END C=2, class_weight=balanced, penalty=l2;, score=0.966 total time=   0.2s
# [CV 5/10; 34/44] START C=2, class_weight=balanced, penalty=l2...................
# [CV 5/10; 34/44] END C=2, class_weight=balanced, penalty=l2;, score=0.946 total time=   0.2s
# [CV 6/10; 34/44] START C=2, class_weight=balanced, penalty=l2...................
# [CV 6/10; 34/44] END C=2, class_weight=balanced, penalty=l2;, score=0.941 total time=   0.2s
# [CV 1/10; 35/44] START C=2, class_weight=None, penalty=l1.......................
# [CV 1/10; 35/44] END C=2, class_weight=None, penalty=l1;, score=0.951 total time=   0.3s
# [CV 2/10; 35/44] START C=2, class_weight=None, penalty=l1.......................
# [CV 2/10; 35/44] END C=2, class_weight=None, penalty=l1;, score=0.940 total time=   0.5s
# [CV 3/10; 35/44] START C=2, class_weight=None, penalty=l1.......................
# [CV 3/10; 35/44] END C=2, class_weight=None, penalty=l1;, score=0.943 total time=   0.4s
# [CV 4/10; 35/44] START C=2, class_weight=None, penalty=l1.......................
# [CV 4/10; 35/44] END C=2, class_weight=None, penalty=l1;, score=0.959 total time=   0.3s
# [CV 3/10; 36/44] START C=2, class_weight=None, penalty=l2.......................
# [CV 3/10; 36/44] END C=2, class_weight=None, penalty=l2;, score=0.943 total time=   0.2s
# [CV 4/10; 36/44] START C=2, class_weight=None, penalty=l2.......................
# [CV 4/10; 36/44] END C=2, class_weight=None, penalty=l2;, score=0.958 total time=   0.2s
# [CV 5/10; 36/44] START C=2, class_weight=None, penalty=l2.......................
# [CV 5/10; 36/44] END C=2, class_weight=None, penalty=l2;, score=0.938 total time=   0.1s
# [CV 6/10; 36/44] START C=2, class_weight=None, penalty=l2.......................
# [CV 6/10; 36/44] END C=2, class_weight=None, penalty=l2;, score=0.928 total time=   0.1s
# [CV 1/10; 37/44] START C=5, class_weight=balanced, penalty=l1...................
# [CV 1/10; 37/44] END C=5, class_weight=balanced, penalty=l1;, score=0.957 total time=   2.6s
# [CV 2/10; 37/44] START C=5, class_weight=balanced, penalty=l1...................
# [CV 2/10; 37/44] END C=5, class_weight=balanced, penalty=l1;, score=0.945 total time=   1.8s
# [CV 3/10; 37/44] START C=5, class_weight=balanced, penalty=l1...................
# [CV 3/10; 37/44] END C=5, class_weight=balanced, penalty=l1;, score=0.945 total time=   1.7s
# [CV 4/10; 37/44] START C=5, class_weight=balanced, penalty=l1...................
# [CV 4/10; 37/44] END C=5, class_weight=balanced, penalty=l1;, score=0.966 total time=   1.3s
# [CV 3/10; 44/44] START C=10, class_weight=None, penalty=l2......................
# [CV 3/10; 44/44] END C=10, class_weight=None, penalty=l2;, score=0.944 total time=   0.2s
# [CV 10/10; 44/44] START C=10, class_weight=None, penalty=l2.....................
# [CV 10/10; 44/44] END C=10, class_weight=None, penalty=l2;, score=0.936 total time=   0.1s
# [CV 5/10; 1/40] START C=0.01, class_weight=balanced, penalty=l1.................
# [CV 5/10; 1/40] END C=0.01, class_weight=balanced, penalty=l1;, score=0.953 total time=   0.1s
# [CV 5/10; 2/40] START C=0.01, class_weight=balanced, penalty=l2.................
# [CV 5/10; 2/40] END C=0.01, class_weight=balanced, penalty=l2;, score=0.951 total time=   0.1s
# [CV 1/10; 4/40] START C=0.01, class_weight=None, penalty=l2.....................
# [CV 1/10; 4/40] END C=0.01, class_weight=None, penalty=l2;, score=0.949 total time=   0.1s
# [CV 2/10; 4/40] START C=0.01, class_weight=None, penalty=l2.....................
# [CV 2/10; 4/40] END C=0.01, class_weight=None, penalty=l2;, score=0.941 total time=   0.1s
# [CV 7/10; 5/40] START C=0.02, class_weight=balanced, penalty=l1.................
# [CV 7/10; 5/40] END C=0.02, class_weight=balanced, penalty=l1;, score=0.961 total time=   0.2s
# [CV 8/10; 5/40] START C=0.02, class_weight=balanced, penalty=l1.................
# [CV 8/10; 5/40] END C=0.02, class_weight=balanced, penalty=l1;, score=0.954 total time=   0.1s
# [CV 1/10; 7/40] START C=0.02, class_weight=None, penalty=l1.....................
# [CV 1/10; 7/40] END C=0.02, class_weight=None, penalty=l1;, score=0.949 total time=   0.1s
# [CV 2/10; 7/40] START C=0.02, class_weight=None, penalty=l1.....................
# [CV 2/10; 7/40] END C=0.02, class_weight=None, penalty=l1;, score=0.942 total time=   0.1s
# [CV 3/10; 8/40] START C=0.02, class_weight=None, penalty=l2.....................
# [CV 3/10; 8/40] END C=0.02, class_weight=None, penalty=l2;, score=0.944 total time=   0.1s
# [CV 4/10; 8/40] START C=0.02, class_weight=None, penalty=l2.....................
# [CV 4/10; 8/40] END C=0.02, class_weight=None, penalty=l2;, score=0.957 total time=   0.1s
# [CV 1/10; 10/40] START C=0.3, class_weight=balanced, penalty=l2.................
# [CV 1/10; 10/40] END C=0.3, class_weight=balanced, penalty=l2;, score=0.957 total time=   0.2s
# [CV 2/10; 10/40] START C=0.3, class_weight=balanced, penalty=l2.................
# [CV 2/10; 10/40] END C=0.3, class_weight=balanced, penalty=l2;, score=0.945 total time=   0.2s
# [CV 7/10; 10/40] START C=0.3, class_weight=balanced, penalty=l2.................
# [CV 7/10; 10/40] END C=0.3, class_weight=balanced, penalty=l2;, score=0.956 total time=   0.2s
# [CV 8/10; 10/40] START C=0.3, class_weight=balanced, penalty=l2.................
# [CV 8/10; 10/40] END C=0.3, class_weight=balanced, penalty=l2;, score=0.953 total time=   0.2s
# [CV 3/10; 11/40] START C=0.3, class_weight=None, penalty=l1.....................
# [CV 3/10; 11/40] END C=0.3, class_weight=None, penalty=l1;, score=0.945 total time=   0.3s
# [CV 4/10; 11/40] START C=0.3, class_weight=None, penalty=l1.....................
# [CV 4/10; 11/40] END C=0.3, class_weight=None, penalty=l1;, score=0.959 total time=   0.2s
# [CV 9/10; 11/40] START C=0.3, class_weight=None, penalty=l1.....................
# [CV 9/10; 11/40] END C=0.3, class_weight=None, penalty=l1;, score=0.966 total time=   0.3s
# [CV 10/10; 11/40] START C=0.3, class_weight=None, penalty=l1....................
# [CV 10/10; 11/40] END C=0.3, class_weight=None, penalty=l1;, score=0.939 total time=   0.4s
# [CV 1/10; 13/40] START C=0.04, class_weight=balanced, penalty=l1................
# [CV 1/10; 13/40] END C=0.04, class_weight=balanced, penalty=l1;, score=0.958 total time=   0.2s
# [CV 2/10; 13/40] START C=0.04, class_weight=balanced, penalty=l1................
# [CV 2/10; 13/40] END C=0.04, class_weight=balanced, penalty=l1;, score=0.949 total time=   0.4s
# [CV 7/10; 13/40] START C=0.04, class_weight=balanced, penalty=l1................
# [CV 7/10; 13/40] END C=0.04, class_weight=balanced, penalty=l1;, score=0.961 total time=   0.3s
# [CV 8/10; 13/40] START C=0.04, class_weight=balanced, penalty=l1................
# [CV 8/10; 13/40] END C=0.04, class_weight=balanced, penalty=l1;, score=0.955 total time=   0.3s
# [CV 7/10; 14/40] START C=0.04, class_weight=balanced, penalty=l2................
# [CV 7/10; 14/40] END C=0.04, class_weight=balanced, penalty=l2;, score=0.959 total time=   0.2s
# [CV 8/10; 14/40] START C=0.04, class_weight=balanced, penalty=l2................
# [CV 8/10; 14/40] END C=0.04, class_weight=balanced, penalty=l2;, score=0.954 total time=   0.1s
# [CV 3/10; 15/40] START C=0.04, class_weight=None, penalty=l1....................
# [CV 3/10; 15/40] END C=0.04, class_weight=None, penalty=l1;, score=0.944 total time=   0.1s
# [CV 4/10; 15/40] START C=0.04, class_weight=None, penalty=l1....................
# [CV 4/10; 15/40] END C=0.04, class_weight=None, penalty=l1;, score=0.956 total time=   0.1s
# [CV 7/10; 15/40] START C=0.04, class_weight=None, penalty=l1....................
# [CV 7/10; 15/40] END C=0.04, class_weight=None, penalty=l1;, score=0.949 total time=   0.2s
# [CV 8/10; 15/40] START C=0.04, class_weight=None, penalty=l1....................
# [CV 8/10; 15/40] END C=0.04, class_weight=None, penalty=l1;, score=0.934 total time=   0.1s
# [CV 5/10; 16/40] START C=0.04, class_weight=None, penalty=l2....................
# [CV 5/10; 16/40] END C=0.04, class_weight=None, penalty=l2;, score=0.941 total time=   0.1s
# [CV 6/10; 16/40] START C=0.04, class_weight=None, penalty=l2....................
# [CV 6/10; 16/40] END C=0.04, class_weight=None, penalty=l2;, score=0.925 total time=   0.1s
# [CV 1/10; 17/40] START C=0.05, class_weight=balanced, penalty=l1................
# [CV 1/10; 17/40] END C=0.05, class_weight=balanced, penalty=l1;, score=0.958 total time=   0.2s
# [CV 2/10; 17/40] START C=0.05, class_weight=balanced, penalty=l1................
# [CV 2/10; 17/40] END C=0.05, class_weight=balanced, penalty=l1;, score=0.948 total time=   0.4s
# [CV 3/10; 18/40] START C=0.05, class_weight=balanced, penalty=l2................
# [CV 3/10; 18/40] END C=0.05, class_weight=balanced, penalty=l2;, score=0.951 total time=   0.2s
# [CV 4/10; 18/40] START C=0.05, class_weight=balanced, penalty=l2................
# [CV 4/10; 18/40] END C=0.05, class_weight=balanced, penalty=l2;, score=0.965 total time=   0.1s
# [CV 9/10; 18/40] START C=0.05, class_weight=balanced, penalty=l2................
# [CV 9/10; 18/40] END C=0.05, class_weight=balanced, penalty=l2;, score=0.965 total time=   0.1s
# [CV 10/10; 18/40] START C=0.05, class_weight=balanced, penalty=l2...............
# [CV 10/10; 18/40] END C=0.05, class_weight=balanced, penalty=l2;, score=0.953 total time=   0.2s
# [CV 6/10; 20/40] START C=0.05, class_weight=None, penalty=l2....................
# [CV 6/10; 20/40] END C=0.05, class_weight=None, penalty=l2;, score=0.926 total time=   0.1s
# [CV 5/10; 21/40] START C=0.06, class_weight=balanced, penalty=l1................
# [CV 5/10; 21/40] END C=0.06, class_weight=balanced, penalty=l1;, score=0.953 total time=   0.5s
# [CV 3/10; 22/40] START C=0.06, class_weight=balanced, penalty=l2................
# [CV 3/10; 22/40] END C=0.06, class_weight=balanced, penalty=l2;, score=0.951 total time=   0.2s
# [CV 10/10; 22/40] START C=0.06, class_weight=balanced, penalty=l2...............
# [CV 10/10; 22/40] END C=0.06, class_weight=balanced, penalty=l2;, score=0.953 total time=   0.1s
# [CV 10/10; 23/40] START C=0.06, class_weight=None, penalty=l1...................
# [CV 10/10; 23/40] END C=0.06, class_weight=None, penalty=l1;, score=0.937 total time=   0.1s
# [CV 7/10; 24/40] START C=0.06, class_weight=None, penalty=l2....................
# [CV 7/10; 24/40] END C=0.06, class_weight=None, penalty=l2;, score=0.950 total time=   0.1s
# [CV 3/10; 25/40] START C=0.07, class_weight=balanced, penalty=l1................
# [CV 3/10; 25/40] END C=0.07, class_weight=balanced, penalty=l1;, score=0.954 total time=   0.3s
# [CV 10/10; 25/40] START C=0.07, class_weight=balanced, penalty=l1...............
# [CV 10/10; 25/40] END C=0.07, class_weight=balanced, penalty=l1;, score=0.955 total time=   0.4s
# [CV 5/10; 27/40] START C=0.07, class_weight=None, penalty=l1....................
# [CV 5/10; 27/40] END C=0.07, class_weight=None, penalty=l1;, score=0.943 total time=   0.1s
# [CV 1/10; 28/40] START C=0.07, class_weight=None, penalty=l2....................
# [CV 1/10; 28/40] END C=0.07, class_weight=None, penalty=l2;, score=0.949 total time=   0.1s
# [CV 8/10; 28/40] START C=0.07, class_weight=None, penalty=l2....................
# [CV 8/10; 28/40] END C=0.07, class_weight=None, penalty=l2;, score=0.934 total time=   0.1s
# [CV 7/10; 29/40] START C=0.08, class_weight=balanced, penalty=l1................
# [CV 7/10; 29/40] END C=0.08, class_weight=balanced, penalty=l1;, score=0.961 total time=   0.4s
# [CV 1/10; 30/40] START C=0.08, class_weight=balanced, penalty=l2................
# [CV 1/10; 30/40] END C=0.08, class_weight=balanced, penalty=l2;, score=0.957 total time=   0.2s
# [CV 6/10; 30/40] START C=0.08, class_weight=balanced, penalty=l2................
# [CV 6/10; 30/40] END C=0.08, class_weight=balanced, penalty=l2;, score=0.942 total time=   0.2s
# [CV 4/10; 31/40] START C=0.08, class_weight=None, penalty=l1....................
# [CV 4/10; 31/40] END C=0.08, class_weight=None, penalty=l1;, score=0.957 total time=   0.3s
# [CV 7/10; 32/40] START C=0.08, class_weight=None, penalty=l2....................
# [CV 7/10; 32/40] END C=0.08, class_weight=None, penalty=l2;, score=0.950 total time=   0.1s
# [CV 5/10; 33/40] START C=0.09, class_weight=balanced, penalty=l1................
# [CV 5/10; 33/40] END C=0.09, class_weight=balanced, penalty=l1;, score=0.952 total time=   0.4s
# [CV 9/10; 33/40] START C=0.09, class_weight=balanced, penalty=l1................
# [CV 9/10; 33/40] END C=0.09, class_weight=balanced, penalty=l1;, score=0.964 total time=   0.5s
# [CV 9/10; 34/40] START C=0.09, class_weight=balanced, penalty=l2................
# [CV 9/10; 34/40] END C=0.09, class_weight=balanced, penalty=l2;, score=0.965 total time=   0.2s
# [CV 9/10; 35/40] START C=0.09, class_weight=None, penalty=l1....................
# [CV 9/10; 35/40] END C=0.09, class_weight=None, penalty=l1;, score=0.964 total time=   0.2s
# [CV 5/10; 36/40] START C=0.09, class_weight=None, penalty=l2....................
# [CV 5/10; 36/40] END C=0.09, class_weight=None, penalty=l2;, score=0.941 total time=   0.1s
# [CV 1/10; 37/40] START C=0.1, class_weight=balanced, penalty=l1.................
# [CV 1/10; 37/40] END C=0.1, class_weight=balanced, penalty=l1;, score=0.958 total time=   0.7s
# [CV 9/10; 37/40] START C=0.1, class_weight=balanced, penalty=l1.................
# [CV 9/10; 37/40] END C=0.1, class_weight=balanced, penalty=l1;, score=0.964 total time=   0.8s
# [CV 7/10; 40/40] START C=0.1, class_weight=None, penalty=l2.....................
# [CV 7/10; 40/40] END C=0.1, class_weight=None, penalty=l2;, score=0.950 total time=   0.1s
# [CV 6/10; 1/44] START C=0.0001, class_weight=balanced, penalty=l1...............
# [CV 6/10; 1/44] END C=0.0001, class_weight=balanced, penalty=l1;, score=0.909 total time=   0.0s
# [CV 1/10; 3/44] START C=0.0001, class_weight=None, penalty=l1...................
# [CV 1/10; 3/44] END C=0.0001, class_weight=None, penalty=l1;, score=0.850 total time=   0.0s
# [CV 4/10; 3/44] START C=0.0001, class_weight=None, penalty=l1...................
# [CV 4/10; 3/44] END C=0.0001, class_weight=None, penalty=l1;, score=0.909 total time=   0.0s
# [CV 2/10; 4/44] START C=0.0001, class_weight=None, penalty=l2...................
# [CV 2/10; 4/44] END C=0.0001, class_weight=None, penalty=l2;, score=0.942 total time=   0.1s
# [CV 10/10; 4/44] START C=0.0001, class_weight=None, penalty=l2..................
# [CV 10/10; 4/44] END C=0.0001, class_weight=None, penalty=l2;, score=0.936 total time=   0.0s
# [CV 7/10; 5/44] START C=0.0005, class_weight=balanced, penalty=l1...............
# [CV 7/10; 5/44] END C=0.0005, class_weight=balanced, penalty=l1;, score=0.962 total time=   0.0s
# [CV 9/10; 6/44] START C=0.0005, class_weight=balanced, penalty=l2...............
# [CV 9/10; 6/44] END C=0.0005, class_weight=balanced, penalty=l2;, score=0.964 total time=   0.1s
# [CV 10/10; 6/44] START C=0.0005, class_weight=balanced, penalty=l2..............
# [CV 10/10; 6/44] END C=0.0005, class_weight=balanced, penalty=l2;, score=0.956 total time=   0.1s
# [CV 7/10; 8/44] START C=0.0005, class_weight=None, penalty=l2...................
# [CV 7/10; 8/44] END C=0.0005, class_weight=None, penalty=l2;, score=0.949 total time=   0.1s
# [CV 8/10; 8/44] START C=0.0005, class_weight=None, penalty=l2...................
# [CV 8/10; 8/44] END C=0.0005, class_weight=None, penalty=l2;, score=0.935 total time=   0.1s
# [CV 9/10; 11/44] START C=0.001, class_weight=None, penalty=l1...................
# [CV 9/10; 11/44] END C=0.001, class_weight=None, penalty=l1;, score=0.963 total time=   0.0s
# [CV 10/10; 11/44] START C=0.001, class_weight=None, penalty=l1..................
# [CV 10/10; 11/44] END C=0.001, class_weight=None, penalty=l1;, score=0.938 total time=   0.0s
# [CV 1/10; 12/44] START C=0.001, class_weight=None, penalty=l2...................
# [CV 1/10; 12/44] END C=0.001, class_weight=None, penalty=l2;, score=0.949 total time=   0.1s
# [CV 2/10; 12/44] START C=0.001, class_weight=None, penalty=l2...................
# [CV 2/10; 12/44] END C=0.001, class_weight=None, penalty=l2;, score=0.942 total time=   0.0s
# [CV 3/10; 14/44] START C=0.005, class_weight=balanced, penalty=l2...............
# [CV 3/10; 14/44] END C=0.005, class_weight=balanced, penalty=l2;, score=0.954 total time=   0.1s
# [CV 4/10; 14/44] START C=0.005, class_weight=balanced, penalty=l2...............
# [CV 4/10; 14/44] END C=0.005, class_weight=balanced, penalty=l2;, score=0.963 total time=   0.1s
# [CV 5/10; 14/44] START C=0.005, class_weight=balanced, penalty=l2...............
# [CV 5/10; 14/44] END C=0.005, class_weight=balanced, penalty=l2;, score=0.952 total time=   0.1s
# [CV 6/10; 14/44] START C=0.005, class_weight=balanced, penalty=l2...............
# [CV 6/10; 14/44] END C=0.005, class_weight=balanced, penalty=l2;, score=0.941 total time=   0.1s
# [CV 9/10; 17/44] START C=0.01, class_weight=balanced, penalty=l1................
# [CV 9/10; 17/44] END C=0.01, class_weight=balanced, penalty=l1;, score=0.963 total time=   0.1s
# [CV 10/10; 17/44] START C=0.01, class_weight=balanced, penalty=l1...............
# [CV 10/10; 17/44] END C=0.01, class_weight=balanced, penalty=l1;, score=0.956 total time=   0.1s
# [CV 1/10; 18/44] START C=0.01, class_weight=balanced, penalty=l2................
# [CV 1/10; 18/44] END C=0.01, class_weight=balanced, penalty=l2;, score=0.958 total time=   0.1s
# [CV 2/10; 18/44] START C=0.01, class_weight=balanced, penalty=l2................
# [CV 2/10; 18/44] END C=0.01, class_weight=balanced, penalty=l2;, score=0.947 total time=   0.1s
# [CV 9/10; 21/44] START C=0.05, class_weight=balanced, penalty=l1................
# [CV 9/10; 21/44] END C=0.05, class_weight=balanced, penalty=l1;, score=0.964 total time=   0.4s
# [CV 10/10; 21/44] START C=0.05, class_weight=balanced, penalty=l1...............
# [CV 10/10; 21/44] END C=0.05, class_weight=balanced, penalty=l1;, score=0.955 total time=   0.4s
# [CV 1/10; 22/44] START C=0.05, class_weight=balanced, penalty=l2................
# [CV 1/10; 22/44] END C=0.05, class_weight=balanced, penalty=l2;, score=0.957 total time=   0.1s
# [CV 2/10; 22/44] START C=0.05, class_weight=balanced, penalty=l2................
# [CV 2/10; 22/44] END C=0.05, class_weight=balanced, penalty=l2;, score=0.945 total time=   0.2s
# [CV 3/10; 26/44] START C=0.1, class_weight=balanced, penalty=l2.................
# [CV 3/10; 26/44] END C=0.1, class_weight=balanced, penalty=l2;, score=0.951 total time=   0.1s
# [CV 4/10; 26/44] START C=0.1, class_weight=balanced, penalty=l2.................
# [CV 4/10; 26/44] END C=0.1, class_weight=balanced, penalty=l2;, score=0.966 total time=   0.1s
# [CV 5/10; 26/44] START C=0.1, class_weight=balanced, penalty=l2.................
# [CV 5/10; 26/44] END C=0.1, class_weight=balanced, penalty=l2;, score=0.948 total time=   0.2s
# [CV 6/10; 26/44] START C=0.1, class_weight=balanced, penalty=l2.................
# [CV 6/10; 26/44] END C=0.1, class_weight=balanced, penalty=l2;, score=0.942 total time=   0.2s
# [CV 3/10; 28/44] START C=0.1, class_weight=None, penalty=l2.....................
# [CV 3/10; 28/44] END C=0.1, class_weight=None, penalty=l2;, score=0.944 total time=   0.1s
# [CV 4/10; 28/44] START C=0.1, class_weight=None, penalty=l2.....................
# [CV 4/10; 28/44] END C=0.1, class_weight=None, penalty=l2;, score=0.957 total time=   0.1s
# [CV 5/10; 28/44] START C=0.1, class_weight=None, penalty=l2.....................
# [CV 5/10; 28/44] END C=0.1, class_weight=None, penalty=l2;, score=0.941 total time=   0.1s
# [CV 6/10; 28/44] START C=0.1, class_weight=None, penalty=l2.....................
# [CV 6/10; 28/44] END C=0.1, class_weight=None, penalty=l2;, score=0.927 total time=   0.1s
# [CV 9/10; 29/44] START C=1, class_weight=balanced, penalty=l1...................
# [CV 9/10; 29/44] END C=1, class_weight=balanced, penalty=l1;, score=0.966 total time=   2.2s
# [CV 10/10; 29/44] START C=1, class_weight=balanced, penalty=l1..................
# [CV 10/10; 29/44] END C=1, class_weight=balanced, penalty=l1;, score=0.953 total time=   1.9s
# [CV 1/10; 30/44] START C=1, class_weight=balanced, penalty=l2...................
# [CV 1/10; 30/44] END C=1, class_weight=balanced, penalty=l2;, score=0.957 total time=   0.2s
# [CV 2/10; 30/44] START C=1, class_weight=balanced, penalty=l2...................
# [CV 2/10; 30/44] END C=1, class_weight=balanced, penalty=l2;, score=0.945 total time=   0.2s
# [CV 9/10; 35/44] START C=2, class_weight=None, penalty=l1.......................
# [CV 9/10; 35/44] END C=2, class_weight=None, penalty=l1;, score=0.967 total time=   0.6s
# [CV 10/10; 35/44] START C=2, class_weight=None, penalty=l1......................
# [CV 10/10; 35/44] END C=2, class_weight=None, penalty=l1;, score=0.938 total time=   0.4s
# [CV 1/10; 36/44] START C=2, class_weight=None, penalty=l2.......................
# [CV 1/10; 36/44] END C=2, class_weight=None, penalty=l2;, score=0.949 total time=   0.2s
# [CV 2/10; 36/44] START C=2, class_weight=None, penalty=l2.......................
# [CV 2/10; 36/44] END C=2, class_weight=None, penalty=l2;, score=0.938 total time=   0.2s
# [CV 9/10; 37/44] START C=5, class_weight=balanced, penalty=l1...................
# [CV 9/10; 37/44] END C=5, class_weight=balanced, penalty=l1;, score=0.966 total time=   1.2s
# [CV 7/10; 38/44] START C=5, class_weight=balanced, penalty=l2...................
# [CV 7/10; 38/44] END C=5, class_weight=balanced, penalty=l2;, score=0.955 total time=   0.2s
# [CV 9/10; 38/44] START C=5, class_weight=balanced, penalty=l2...................
# [CV 9/10; 38/44] END C=5, class_weight=balanced, penalty=l2;, score=0.966 total time=   0.3s
# [CV 4/10; 39/44] START C=5, class_weight=None, penalty=l1.......................
# [CV 4/10; 39/44] END C=5, class_weight=None, penalty=l1;, score=0.959 total time=   0.3s
# [CV 8/10; 39/44] START C=5, class_weight=None, penalty=l1.......................
# [CV 8/10; 39/44] END C=5, class_weight=None, penalty=l1;, score=0.930 total time=   0.8s
# [CV 5/10; 41/44] START C=10, class_weight=balanced, penalty=l1..................
# [CV 5/10; 41/44] END C=10, class_weight=balanced, penalty=l1;, score=0.946 total time=   1.5s
# [CV 8/10; 41/44] START C=10, class_weight=balanced, penalty=l1..................
# [CV 8/10; 41/44] END C=10, class_weight=balanced, penalty=l1;, score=0.950 total time=   2.1s
# [CV 6/10; 43/44] START C=10, class_weight=None, penalty=l1......................
# [CV 6/10; 43/44] END C=10, class_weight=None, penalty=l1;, score=0.928 total time=   0.7s
# [CV 6/10; 44/44] START C=10, class_weight=None, penalty=l2......................
# [CV 6/10; 44/44] END C=10, class_weight=None, penalty=l2;, score=0.928 total time=   0.2s
# [CV 7/10; 1/40] START C=0.01, class_weight=balanced, penalty=l1.................
# [CV 7/10; 1/40] END C=0.01, class_weight=balanced, penalty=l1;, score=0.962 total time=   0.1s
# [CV 6/10; 2/40] START C=0.01, class_weight=balanced, penalty=l2.................
# [CV 6/10; 2/40] END C=0.01, class_weight=balanced, penalty=l2;, score=0.941 total time=   0.1s
# [CV 9/10; 3/40] START C=0.01, class_weight=None, penalty=l1.....................
# [CV 9/10; 3/40] END C=0.01, class_weight=None, penalty=l1;, score=0.963 total time=   0.0s
# [CV 10/10; 3/40] START C=0.01, class_weight=None, penalty=l1....................
# [CV 10/10; 3/40] END C=0.01, class_weight=None, penalty=l1;, score=0.937 total time=   0.1s
# [CV 7/10; 4/40] START C=0.01, class_weight=None, penalty=l2.....................
# [CV 7/10; 4/40] END C=0.01, class_weight=None, penalty=l2;, score=0.950 total time=   0.1s
# [CV 8/10; 4/40] START C=0.01, class_weight=None, penalty=l2.....................
# [CV 8/10; 4/40] END C=0.01, class_weight=None, penalty=l2;, score=0.934 total time=   0.1s
# [CV 1/10; 6/40] START C=0.02, class_weight=balanced, penalty=l2.................
# [CV 1/10; 6/40] END C=0.02, class_weight=balanced, penalty=l2;, score=0.958 total time=   0.2s
# [CV 2/10; 6/40] START C=0.02, class_weight=balanced, penalty=l2.................
# [CV 2/10; 6/40] END C=0.02, class_weight=balanced, penalty=l2;, score=0.946 total time=   0.1s
# [CV 1/10; 8/40] START C=0.02, class_weight=None, penalty=l2.....................
# [CV 1/10; 8/40] END C=0.02, class_weight=None, penalty=l2;, score=0.949 total time=   0.1s
# [CV 2/10; 8/40] START C=0.02, class_weight=None, penalty=l2.....................
# [CV 2/10; 8/40] END C=0.02, class_weight=None, penalty=l2;, score=0.940 total time=   0.1s
# [CV 7/10; 9/40] START C=0.3, class_weight=balanced, penalty=l1..................
# [CV 7/10; 9/40] END C=0.3, class_weight=balanced, penalty=l1;, score=0.957 total time=   2.6s
# [CV 8/10; 9/40] START C=0.3, class_weight=balanced, penalty=l1..................
# [CV 8/10; 9/40] END C=0.3, class_weight=balanced, penalty=l1;, score=0.953 total time=   1.7s
# [CV 3/10; 17/40] START C=0.05, class_weight=balanced, penalty=l1................
# [CV 3/10; 17/40] END C=0.05, class_weight=balanced, penalty=l1;, score=0.954 total time=   0.3s
# [CV 4/10; 17/40] START C=0.05, class_weight=balanced, penalty=l1................
# [CV 4/10; 17/40] END C=0.05, class_weight=balanced, penalty=l1;, score=0.962 total time=   0.4s
# [CV 7/10; 18/40] START C=0.05, class_weight=balanced, penalty=l2................
# [CV 7/10; 18/40] END C=0.05, class_weight=balanced, penalty=l2;, score=0.959 total time=   0.1s
# [CV 8/10; 18/40] START C=0.05, class_weight=balanced, penalty=l2................
# [CV 8/10; 18/40] END C=0.05, class_weight=balanced, penalty=l2;, score=0.954 total time=   0.2s
# [CV 7/10; 19/40] START C=0.05, class_weight=None, penalty=l1....................
# [CV 7/10; 19/40] END C=0.05, class_weight=None, penalty=l1;, score=0.949 total time=   0.1s
# [CV 8/10; 19/40] START C=0.05, class_weight=None, penalty=l1....................
# [CV 8/10; 19/40] END C=0.05, class_weight=None, penalty=l1;, score=0.934 total time=   0.1s
# [CV 8/10; 20/40] START C=0.05, class_weight=None, penalty=l2....................
# [CV 8/10; 20/40] END C=0.05, class_weight=None, penalty=l2;, score=0.934 total time=   0.1s
# [CV 4/10; 21/40] START C=0.06, class_weight=balanced, penalty=l1................
# [CV 4/10; 21/40] END C=0.06, class_weight=balanced, penalty=l1;, score=0.963 total time=   0.4s
# [CV 2/10; 22/40] START C=0.06, class_weight=balanced, penalty=l2................
# [CV 2/10; 22/40] END C=0.06, class_weight=balanced, penalty=l2;, score=0.945 total time=   0.1s
# [CV 7/10; 22/40] START C=0.06, class_weight=balanced, penalty=l2................
# [CV 7/10; 22/40] END C=0.06, class_weight=balanced, penalty=l2;, score=0.959 total time=   0.2s
# [CV 4/10; 23/40] START C=0.06, class_weight=None, penalty=l1....................
# [CV 4/10; 23/40] END C=0.06, class_weight=None, penalty=l1;, score=0.956 total time=   0.1s
# [CV 9/10; 23/40] START C=0.06, class_weight=None, penalty=l1....................
# [CV 9/10; 23/40] END C=0.06, class_weight=None, penalty=l1;, score=0.964 total time=   0.2s
# [CV 9/10; 24/40] START C=0.06, class_weight=None, penalty=l2....................
# [CV 9/10; 24/40] END C=0.06, class_weight=None, penalty=l2;, score=0.965 total time=   0.2s
# [CV 8/10; 25/40] START C=0.07, class_weight=balanced, penalty=l1................
# [CV 8/10; 25/40] END C=0.07, class_weight=balanced, penalty=l1;, score=0.955 total time=   0.6s
# [CV 10/10; 26/40] START C=0.07, class_weight=balanced, penalty=l2...............
# [CV 10/10; 26/40] END C=0.07, class_weight=balanced, penalty=l2;, score=0.953 total time=   0.1s
# [CV 7/10; 27/40] START C=0.07, class_weight=None, penalty=l1....................
# [CV 7/10; 27/40] END C=0.07, class_weight=None, penalty=l1;, score=0.950 total time=   0.1s
# [CV 2/10; 28/40] START C=0.07, class_weight=None, penalty=l2....................
# [CV 2/10; 28/40] END C=0.07, class_weight=None, penalty=l2;, score=0.940 total time=   0.1s
# [CV 9/10; 28/40] START C=0.07, class_weight=None, penalty=l2....................
# [CV 9/10; 28/40] END C=0.07, class_weight=None, penalty=l2;, score=0.965 total time=   0.1s
# [CV 5/10; 29/40] START C=0.08, class_weight=balanced, penalty=l1................
# [CV 5/10; 29/40] END C=0.08, class_weight=balanced, penalty=l1;, score=0.952 total time=   0.6s
# [CV 3/10; 30/40] START C=0.08, class_weight=balanced, penalty=l2................
# [CV 3/10; 30/40] END C=0.08, class_weight=balanced, penalty=l2;, score=0.951 total time=   0.2s
# [CV 2/10; 31/40] START C=0.08, class_weight=None, penalty=l1....................
# [CV 2/10; 31/40] END C=0.08, class_weight=None, penalty=l1;, score=0.941 total time=   0.1s
# [CV 8/10; 31/40] START C=0.08, class_weight=None, penalty=l1....................
# [CV 8/10; 31/40] END C=0.08, class_weight=None, penalty=l1;, score=0.935 total time=   0.3s
# [CV 4/10; 33/40] START C=0.09, class_weight=balanced, penalty=l1................
# [CV 4/10; 33/40] END C=0.09, class_weight=balanced, penalty=l1;, score=0.963 total time=   0.8s
# [CV 3/10; 34/40] START C=0.09, class_weight=balanced, penalty=l2................
# [CV 3/10; 34/40] END C=0.09, class_weight=balanced, penalty=l2;, score=0.951 total time=   0.2s
# [CV 2/10; 35/40] START C=0.09, class_weight=None, penalty=l1....................
# [CV 2/10; 35/40] END C=0.09, class_weight=None, penalty=l1;, score=0.941 total time=   0.1s
# [CV 6/10; 35/40] START C=0.09, class_weight=None, penalty=l1....................
# [CV 6/10; 35/40] END C=0.09, class_weight=None, penalty=l1;, score=0.926 total time=   0.4s
# [CV 2/10; 37/40] START C=0.1, class_weight=balanced, penalty=l1.................
# [CV 2/10; 37/40] END C=0.1, class_weight=balanced, penalty=l1;, score=0.947 total time=   0.8s
# [CV 3/10; 38/40] START C=0.1, class_weight=balanced, penalty=l2.................
# [CV 3/10; 38/40] END C=0.1, class_weight=balanced, penalty=l2;, score=0.951 total time=   0.2s
# [CV 6/10; 38/40] START C=0.1, class_weight=balanced, penalty=l2.................
# [CV 6/10; 38/40] END C=0.1, class_weight=balanced, penalty=l2;, score=0.942 total time=   0.2s
# [CV 4/10; 39/40] START C=0.1, class_weight=None, penalty=l1.....................
# [CV 4/10; 39/40] END C=0.1, class_weight=None, penalty=l1;, score=0.957 total time=   0.5s
# [CV 7/10; 1/44] START C=0.0001, class_weight=balanced, penalty=l1...............
# [CV 7/10; 1/44] END C=0.0001, class_weight=balanced, penalty=l1;, score=0.943 total time=   0.0s
# [CV 9/10; 2/44] START C=0.0001, class_weight=balanced, penalty=l2...............
# [CV 9/10; 2/44] END C=0.0001, class_weight=balanced, penalty=l2;, score=0.964 total time=   0.1s
# [CV 3/10; 4/44] START C=0.0001, class_weight=None, penalty=l2...................
# [CV 3/10; 4/44] END C=0.0001, class_weight=None, penalty=l2;, score=0.949 total time=   0.1s
# [CV 4/10; 5/44] START C=0.0005, class_weight=balanced, penalty=l1...............
# [CV 4/10; 5/44] END C=0.0005, class_weight=balanced, penalty=l1;, score=0.957 total time=   0.0s
# [CV 3/10; 6/44] START C=0.0005, class_weight=balanced, penalty=l2...............
# [CV 3/10; 6/44] END C=0.0005, class_weight=balanced, penalty=l2;, score=0.955 total time=   0.1s
# [CV 4/10; 6/44] START C=0.0005, class_weight=balanced, penalty=l2...............
# [CV 4/10; 6/44] END C=0.0005, class_weight=balanced, penalty=l2;, score=0.962 total time=   0.1s
# [CV 1/10; 8/44] START C=0.0005, class_weight=None, penalty=l2...................
# [CV 1/10; 8/44] END C=0.0005, class_weight=None, penalty=l2;, score=0.949 total time=   0.1s
# [CV 2/10; 8/44] START C=0.0005, class_weight=None, penalty=l2...................
# [CV 2/10; 8/44] END C=0.0005, class_weight=None, penalty=l2;, score=0.942 total time=   0.1s
# [CV 3/10; 10/44] START C=0.001, class_weight=balanced, penalty=l2...............
# [CV 3/10; 10/44] END C=0.001, class_weight=balanced, penalty=l2;, score=0.954 total time=   0.1s
# [CV 4/10; 10/44] START C=0.001, class_weight=balanced, penalty=l2...............
# [CV 4/10; 10/44] END C=0.001, class_weight=balanced, penalty=l2;, score=0.962 total time=   0.1s
# [CV 5/10; 10/44] START C=0.001, class_weight=balanced, penalty=l2...............
# [CV 5/10; 10/44] END C=0.001, class_weight=balanced, penalty=l2;, score=0.953 total time=   0.1s
# [CV 6/10; 10/44] START C=0.001, class_weight=balanced, penalty=l2...............
# [CV 6/10; 10/44] END C=0.001, class_weight=balanced, penalty=l2;, score=0.940 total time=   0.1s
# [CV 7/10; 14/44] START C=0.005, class_weight=balanced, penalty=l2...............
# [CV 7/10; 14/44] END C=0.005, class_weight=balanced, penalty=l2;, score=0.961 total time=   0.1s
# [CV 8/10; 14/44] START C=0.005, class_weight=balanced, penalty=l2...............
# [CV 8/10; 14/44] END C=0.005, class_weight=balanced, penalty=l2;, score=0.954 total time=   0.1s
# [CV 9/10; 14/44] START C=0.005, class_weight=balanced, penalty=l2...............
# [CV 9/10; 14/44] END C=0.005, class_weight=balanced, penalty=l2;, score=0.964 total time=   0.1s
# [CV 10/10; 14/44] START C=0.005, class_weight=balanced, penalty=l2..............
# [CV 10/10; 14/44] END C=0.005, class_weight=balanced, penalty=l2;, score=0.955 total time=   0.1s
# [CV 7/10; 18/44] START C=0.01, class_weight=balanced, penalty=l2................
# [CV 7/10; 18/44] END C=0.01, class_weight=balanced, penalty=l2;, score=0.961 total time=   0.1s
# [CV 8/10; 18/44] START C=0.01, class_weight=balanced, penalty=l2................
# [CV 8/10; 18/44] END C=0.01, class_weight=balanced, penalty=l2;, score=0.954 total time=   0.1s
# [CV 9/10; 18/44] START C=0.01, class_weight=balanced, penalty=l2................
# [CV 9/10; 18/44] END C=0.01, class_weight=balanced, penalty=l2;, score=0.964 total time=   0.1s
# [CV 10/10; 18/44] START C=0.01, class_weight=balanced, penalty=l2...............
# [CV 10/10; 18/44] END C=0.01, class_weight=balanced, penalty=l2;, score=0.955 total time=   0.1s
# [CV 7/10; 22/44] START C=0.05, class_weight=balanced, penalty=l2................
# [CV 7/10; 22/44] END C=0.05, class_weight=balanced, penalty=l2;, score=0.959 total time=   0.1s
# [CV 8/10; 22/44] START C=0.05, class_weight=balanced, penalty=l2................
# [CV 8/10; 22/44] END C=0.05, class_weight=balanced, penalty=l2;, score=0.954 total time=   0.2s
# [CV 9/10; 22/44] START C=0.05, class_weight=balanced, penalty=l2................
# [CV 9/10; 22/44] END C=0.05, class_weight=balanced, penalty=l2;, score=0.965 total time=   0.2s
# [CV 10/10; 22/44] START C=0.05, class_weight=balanced, penalty=l2...............
# [CV 10/10; 22/44] END C=0.05, class_weight=balanced, penalty=l2;, score=0.953 total time=   0.2s
# [CV 5/10; 25/44] START C=0.1, class_weight=balanced, penalty=l1.................
# [CV 5/10; 25/44] END C=0.1, class_weight=balanced, penalty=l1;, score=0.951 total time=   0.7s
# [CV 6/10; 25/44] START C=0.1, class_weight=balanced, penalty=l1.................
# [CV 6/10; 25/44] END C=0.1, class_weight=balanced, penalty=l1;, score=0.942 total time=   0.6s
# [CV 7/10; 25/44] START C=0.1, class_weight=balanced, penalty=l1.................
# [CV 7/10; 25/44] END C=0.1, class_weight=balanced, penalty=l1;, score=0.960 total time=   0.7s
# [CV 8/10; 25/44] START C=0.1, class_weight=balanced, penalty=l1.................
# [CV 8/10; 25/44] END C=0.1, class_weight=balanced, penalty=l1;, score=0.955 total time=   0.9s
# [CV 3/10; 32/44] START C=1, class_weight=None, penalty=l2.......................
# [CV 3/10; 32/44] END C=1, class_weight=None, penalty=l2;, score=0.943 total time=   0.1s
# [CV 4/10; 32/44] START C=1, class_weight=None, penalty=l2.......................
# [CV 4/10; 32/44] END C=1, class_weight=None, penalty=l2;, score=0.957 total time=   0.1s
# [CV 5/10; 32/44] START C=1, class_weight=None, penalty=l2.......................
# [CV 5/10; 32/44] END C=1, class_weight=None, penalty=l2;, score=0.939 total time=   0.2s
# [CV 6/10; 32/44] START C=1, class_weight=None, penalty=l2.......................
# [CV 6/10; 32/44] END C=1, class_weight=None, penalty=l2;, score=0.927 total time=   0.2s
# [CV 1/10; 33/44] START C=2, class_weight=balanced, penalty=l1...................
# [CV 1/10; 33/44] END C=2, class_weight=balanced, penalty=l1;, score=0.957 total time=   1.1s
# [CV 2/10; 33/44] START C=2, class_weight=balanced, penalty=l1...................
# [CV 2/10; 33/44] END C=2, class_weight=balanced, penalty=l1;, score=0.945 total time=   1.2s
# [CV 3/10; 33/44] START C=2, class_weight=balanced, penalty=l1...................
# [CV 3/10; 33/44] END C=2, class_weight=balanced, penalty=l1;, score=0.949 total time=   1.4s
# [CV 4/10; 33/44] START C=2, class_weight=balanced, penalty=l1...................
# [CV 4/10; 33/44] END C=2, class_weight=balanced, penalty=l1;, score=0.967 total time=   1.3s
# [CV 4/10; 38/44] START C=5, class_weight=balanced, penalty=l2...................
# [CV 4/10; 38/44] END C=5, class_weight=balanced, penalty=l2;, score=0.966 total time=   0.2s
# [CV 8/10; 38/44] START C=5, class_weight=balanced, penalty=l2...................
# [CV 8/10; 38/44] END C=5, class_weight=balanced, penalty=l2;, score=0.951 total time=   0.3s
# [CV 1/10; 39/44] START C=5, class_weight=None, penalty=l1.......................
# [CV 1/10; 39/44] END C=5, class_weight=None, penalty=l1;, score=0.951 total time=   0.4s
# [CV 7/10; 39/44] START C=5, class_weight=None, penalty=l1.......................
# [CV 7/10; 39/44] END C=5, class_weight=None, penalty=l1;, score=0.944 total time=   0.7s
# [CV 8/10; 40/44] START C=5, class_weight=None, penalty=l2.......................
# [CV 8/10; 40/44] END C=5, class_weight=None, penalty=l2;, score=0.933 total time=   0.1s
# [CV 3/10; 41/44] START C=10, class_weight=balanced, penalty=l1..................
# [CV 3/10; 41/44] END C=10, class_weight=balanced, penalty=l1;, score=0.942 total time=   2.0s
# [CV 2/10; 42/44] START C=10, class_weight=balanced, penalty=l2..................
# [CV 2/10; 42/44] END C=10, class_weight=balanced, penalty=l2;, score=0.945 total time=   0.4s
# [CV 4/10; 42/44] START C=10, class_weight=balanced, penalty=l2..................
# [CV 4/10; 42/44] END C=10, class_weight=balanced, penalty=l2;, score=0.967 total time=   0.4s
# [CV 6/10; 42/44] START C=10, class_weight=balanced, penalty=l2..................
# [CV 6/10; 42/44] END C=10, class_weight=balanced, penalty=l2;, score=0.941 total time=   0.3s
# [CV 8/10; 42/44] START C=10, class_weight=balanced, penalty=l2..................
# [CV 8/10; 42/44] END C=10, class_weight=balanced, penalty=l2;, score=0.951 total time=   0.3s
# [CV 1/10; 43/44] START C=10, class_weight=None, penalty=l1......................
# [CV 1/10; 43/44] END C=10, class_weight=None, penalty=l1;, score=0.952 total time=   0.8s
# [CV 10/10; 43/44] START C=10, class_weight=None, penalty=l1.....................
# [CV 10/10; 43/44] END C=10, class_weight=None, penalty=l1;, score=0.938 total time=   0.4s
# [CV 1/10; 1/40] START C=0.01, class_weight=balanced, penalty=l1.................
# [CV 1/10; 1/40] END C=0.01, class_weight=balanced, penalty=l1;, score=0.958 total time=   0.1s
# [CV 9/10; 1/40] START C=0.01, class_weight=balanced, penalty=l1.................
# [CV 9/10; 1/40] END C=0.01, class_weight=balanced, penalty=l1;, score=0.963 total time=   0.1s
# [CV 7/10; 3/40] START C=0.01, class_weight=None, penalty=l1.....................
# [CV 7/10; 3/40] END C=0.01, class_weight=None, penalty=l1;, score=0.950 total time=   0.0s
# [CV 8/10; 3/40] START C=0.01, class_weight=None, penalty=l1.....................
# [CV 8/10; 3/40] END C=0.01, class_weight=None, penalty=l1;, score=0.935 total time=   0.1s
# [CV 9/10; 4/40] START C=0.01, class_weight=None, penalty=l2.....................
# [CV 9/10; 4/40] END C=0.01, class_weight=None, penalty=l2;, score=0.964 total time=   0.1s
# [CV 10/10; 4/40] START C=0.01, class_weight=None, penalty=l2....................
# [CV 10/10; 4/40] END C=0.01, class_weight=None, penalty=l2;, score=0.937 total time=   0.1s
# [CV 9/10; 5/40] START C=0.02, class_weight=balanced, penalty=l1.................
# [CV 9/10; 5/40] END C=0.02, class_weight=balanced, penalty=l1;, score=0.963 total time=   0.1s
# [CV 10/10; 5/40] START C=0.02, class_weight=balanced, penalty=l1................
# [CV 10/10; 5/40] END C=0.02, class_weight=balanced, penalty=l1;, score=0.956 total time=   0.1s
# [CV 9/10; 7/40] START C=0.02, class_weight=None, penalty=l1.....................
# [CV 9/10; 7/40] END C=0.02, class_weight=None, penalty=l1;, score=0.963 total time=   0.1s
# [CV 10/10; 7/40] START C=0.02, class_weight=None, penalty=l1....................
# [CV 10/10; 7/40] END C=0.02, class_weight=None, penalty=l1;, score=0.937 total time=   0.0s
# [CV 3/10; 9/40] START C=0.3, class_weight=balanced, penalty=l1..................
# [CV 3/10; 9/40] END C=0.3, class_weight=balanced, penalty=l1;, score=0.951 total time=   2.1s
# [CV 4/10; 9/40] START C=0.3, class_weight=balanced, penalty=l1..................
# [CV 4/10; 9/40] END C=0.3, class_weight=balanced, penalty=l1;, score=0.966 total time=   2.6s
# [CV 1/10; 18/40] START C=0.05, class_weight=balanced, penalty=l2................
# [CV 1/10; 18/40] END C=0.05, class_weight=balanced, penalty=l2;, score=0.957 total time=   0.1s
# [CV 2/10; 18/40] START C=0.05, class_weight=balanced, penalty=l2................
# [CV 2/10; 18/40] END C=0.05, class_weight=balanced, penalty=l2;, score=0.945 total time=   0.2s
# [CV 5/10; 18/40] START C=0.05, class_weight=balanced, penalty=l2................
# [CV 5/10; 18/40] END C=0.05, class_weight=balanced, penalty=l2;, score=0.949 total time=   0.2s
# [CV 6/10; 18/40] START C=0.05, class_weight=balanced, penalty=l2................
# [CV 6/10; 18/40] END C=0.05, class_weight=balanced, penalty=l2;, score=0.942 total time=   0.1s
# [CV 5/10; 19/40] START C=0.05, class_weight=None, penalty=l1....................
# ...
# [CV 5/10; 39/40] END C=0.1, class_weight=None, penalty=l1;, score=0.944 total time=   0.4s
# [CV 10/10; 40/40] START C=0.1, class_weight=None, penalty=l2....................
# [CV 10/10; 40/40] END C=0.1, class_weight=None, penalty=l2;, score=0.936 total time=   0.1s
# [CV 4/10; 1/44] START C=0.0001, class_weight=balanced, penalty=l1...............
# [CV 4/10; 1/44] END C=0.0001, class_weight=balanced, penalty=l1;, score=0.945 total time=   0.0s
# [CV 9/10; 1/44] START C=0.0001, class_weight=balanced, penalty=l1...............
# [CV 9/10; 1/44] END C=0.0001, class_weight=balanced, penalty=l1;, score=0.944 total time=   0.0s
# [CV 2/10; 2/44] START C=0.0001, class_weight=balanced, penalty=l2...............
# [CV 2/10; 2/44] END C=0.0001, class_weight=balanced, penalty=l2;, score=0.949 total time=   0.1s
# [CV 7/10; 2/44] START C=0.0001, class_weight=balanced, penalty=l2...............
# [CV 7/10; 2/44] END C=0.0001, class_weight=balanced, penalty=l2;, score=0.962 total time=   0.1s
# [CV 3/10; 3/44] START C=0.0001, class_weight=None, penalty=l1...................
# [CV 3/10; 3/44] END C=0.0001, class_weight=None, penalty=l1;, score=0.916 total time=   0.0s
# [CV 9/10; 3/44] START C=0.0001, class_weight=None, penalty=l1...................
# [CV 9/10; 3/44] END C=0.0001, class_weight=None, penalty=l1;, score=0.904 total time=   0.0s
# [CV 4/10; 4/44] START C=0.0001, class_weight=None, penalty=l2...................
# [CV 4/10; 4/44] END C=0.0001, class_weight=None, penalty=l2;, score=0.955 total time=   0.1s
# [CV 3/10; 5/44] START C=0.0005, class_weight=balanced, penalty=l1...............
# [CV 3/10; 5/44] END C=0.0005, class_weight=balanced, penalty=l1;, score=0.955 total time=   0.0s
# [CV 1/10; 6/44] START C=0.0005, class_weight=balanced, penalty=l2...............
# [CV 1/10; 6/44] END C=0.0005, class_weight=balanced, penalty=l2;, score=0.958 total time=   0.0s
# [CV 2/10; 6/44] START C=0.0005, class_weight=balanced, penalty=l2...............
# [CV 2/10; 6/44] END C=0.0005, class_weight=balanced, penalty=l2;, score=0.949 total time=   0.1s
# [CV 3/10; 8/44] START C=0.0005, class_weight=None, penalty=l2...................
# [CV 3/10; 8/44] END C=0.0005, class_weight=None, penalty=l2;, score=0.945 total time=   0.1s
# [CV 4/10; 8/44] START C=0.0005, class_weight=None, penalty=l2...................
# [CV 4/10; 8/44] END C=0.0005, class_weight=None, penalty=l2;, score=0.956 total time=   0.0s
# [CV 7/10; 10/44] START C=0.001, class_weight=balanced, penalty=l2...............
# [CV 7/10; 10/44] END C=0.001, class_weight=balanced, penalty=l2;, score=0.961 total time=   0.1s
# [CV 8/10; 10/44] START C=0.001, class_weight=balanced, penalty=l2...............
# [CV 8/10; 10/44] END C=0.001, class_weight=balanced, penalty=l2;, score=0.954 total time=   0.1s
# [CV 9/10; 10/44] START C=0.001, class_weight=balanced, penalty=l2...............
# [CV 9/10; 10/44] END C=0.001, class_weight=balanced, penalty=l2;, score=0.964 total time=   0.1s
# [CV 10/10; 10/44] START C=0.001, class_weight=balanced, penalty=l2..............
# [CV 10/10; 10/44] END C=0.001, class_weight=balanced, penalty=l2;, score=0.956 total time=   0.1s
# [CV 1/10; 15/44] START C=0.005, class_weight=None, penalty=l1...................
# [CV 1/10; 15/44] END C=0.005, class_weight=None, penalty=l1;, score=0.949 total time=   0.0s
# [CV 2/10; 15/44] START C=0.005, class_weight=None, penalty=l1...................
# [CV 2/10; 15/44] END C=0.005, class_weight=None, penalty=l1;, score=0.942 total time=   0.0s
# [CV 3/10; 15/44] START C=0.005, class_weight=None, penalty=l1...................
# [CV 3/10; 15/44] END C=0.005, class_weight=None, penalty=l1;, score=0.947 total time=   0.0s
# [CV 4/10; 15/44] START C=0.005, class_weight=None, penalty=l1...................
# [CV 4/10; 15/44] END C=0.005, class_weight=None, penalty=l1;, score=0.955 total time=   0.0s
# [CV 9/10; 15/44] START C=0.005, class_weight=None, penalty=l1...................
# [CV 9/10; 15/44] END C=0.005, class_weight=None, penalty=l1;, score=0.964 total time=   0.1s
# [CV 10/10; 15/44] START C=0.005, class_weight=None, penalty=l1..................
# [CV 10/10; 15/44] END C=0.005, class_weight=None, penalty=l1;, score=0.937 total time=   0.1s
# [CV 1/10; 16/44] START C=0.005, class_weight=None, penalty=l2...................
# [CV 1/10; 16/44] END C=0.005, class_weight=None, penalty=l2;, score=0.949 total time=   0.1s
# [CV 2/10; 16/44] START C=0.005, class_weight=None, penalty=l2...................
# [CV 2/10; 16/44] END C=0.005, class_weight=None, penalty=l2;, score=0.941 total time=   0.1s
# [CV 1/10; 19/44] START C=0.01, class_weight=None, penalty=l1....................
# [CV 1/10; 19/44] END C=0.01, class_weight=None, penalty=l1;, score=0.949 total time=   0.1s
# [CV 2/10; 19/44] START C=0.01, class_weight=None, penalty=l1....................
# [CV 2/10; 19/44] END C=0.01, class_weight=None, penalty=l1;, score=0.942 total time=   0.0s
# [CV 3/10; 19/44] START C=0.01, class_weight=None, penalty=l1....................
# [CV 3/10; 19/44] END C=0.01, class_weight=None, penalty=l1;, score=0.946 total time=   0.1s
# [CV 4/10; 19/44] START C=0.01, class_weight=None, penalty=l1....................
# [CV 4/10; 19/44] END C=0.01, class_weight=None, penalty=l1;, score=0.956 total time=   0.1s
# [CV 3/10; 20/44] START C=0.01, class_weight=None, penalty=l2....................
# [CV 3/10; 20/44] END C=0.01, class_weight=None, penalty=l2;, score=0.944 total time=   0.1s
# [CV 4/10; 20/44] START C=0.01, class_weight=None, penalty=l2....................
# [CV 4/10; 20/44] END C=0.01, class_weight=None, penalty=l2;, score=0.957 total time=   0.1s
# [CV 5/10; 20/44] START C=0.01, class_weight=None, penalty=l2....................
# [CV 5/10; 20/44] END C=0.01, class_weight=None, penalty=l2;, score=0.942 total time=   0.1s
# [CV 6/10; 20/44] START C=0.01, class_weight=None, penalty=l2....................
# [CV 6/10; 20/44] END C=0.01, class_weight=None, penalty=l2;, score=0.925 total time=   0.1s
# [CV 9/10; 23/44] START C=0.05, class_weight=None, penalty=l1....................
# [CV 9/10; 23/44] END C=0.05, class_weight=None, penalty=l1;, score=0.964 total time=   0.1s
# [CV 10/10; 23/44] START C=0.05, class_weight=None, penalty=l1...................
# [CV 10/10; 23/44] END C=0.05, class_weight=None, penalty=l1;, score=0.936 total time=   0.2s
# [CV 1/10; 24/44] START C=0.05, class_weight=None, penalty=l2....................
# [CV 1/10; 24/44] END C=0.05, class_weight=None, penalty=l2;, score=0.949 total time=   0.1s
# [CV 2/10; 24/44] START C=0.05, class_weight=None, penalty=l2....................
# [CV 2/10; 24/44] END C=0.05, class_weight=None, penalty=l2;, score=0.940 total time=   0.1s
# [CV 1/10; 25/44] START C=0.1, class_weight=balanced, penalty=l1.................
# [CV 1/10; 25/44] END C=0.1, class_weight=balanced, penalty=l1;, score=0.958 total time=   0.8s
# [CV 2/10; 25/44] START C=0.1, class_weight=balanced, penalty=l1.................
# [CV 2/10; 25/44] END C=0.1, class_weight=balanced, penalty=l1;, score=0.947 total time=   0.7s
# [CV 3/10; 25/44] START C=0.1, class_weight=balanced, penalty=l1.................
# [CV 3/10; 25/44] END C=0.1, class_weight=balanced, penalty=l1;, score=0.953 total time=   0.8s
# [CV 4/10; 25/44] START C=0.1, class_weight=balanced, penalty=l1.................
# [CV 4/10; 25/44] END C=0.1, class_weight=balanced, penalty=l1;, score=0.963 total time=   0.8s
# [CV 7/10; 32/44] START C=1, class_weight=None, penalty=l2.......................
# [CV 7/10; 32/44] END C=1, class_weight=None, penalty=l2;, score=0.950 total time=   0.1s
# [CV 8/10; 32/44] START C=1, class_weight=None, penalty=l2.......................
# [CV 8/10; 32/44] END C=1, class_weight=None, penalty=l2;, score=0.933 total time=   0.1s
# [CV 9/10; 32/44] START C=1, class_weight=None, penalty=l2.......................
# [CV 9/10; 32/44] END C=1, class_weight=None, penalty=l2;, score=0.965 total time=   0.1s
# [CV 10/10; 32/44] START C=1, class_weight=None, penalty=l2......................
# [CV 10/10; 32/44] END C=1, class_weight=None, penalty=l2;, score=0.938 total time=   0.2s
# [CV 5/10; 33/44] START C=2, class_weight=balanced, penalty=l1...................
# [CV 5/10; 33/44] END C=2, class_weight=balanced, penalty=l1;, score=0.946 total time=   1.4s
# [CV 6/10; 33/44] START C=2, class_weight=balanced, penalty=l1...................
# [CV 6/10; 33/44] END C=2, class_weight=balanced, penalty=l1;, score=0.941 total time=   1.1s
# [CV 7/10; 33/44] START C=2, class_weight=balanced, penalty=l1...................
# [CV 7/10; 33/44] END C=2, class_weight=balanced, penalty=l1;, score=0.955 total time=   1.2s
# [CV 8/10; 33/44] START C=2, class_weight=balanced, penalty=l1...................
# [CV 8/10; 33/44] END C=2, class_weight=balanced, penalty=l1;, score=0.950 total time=   1.7s
# [CV 3/10; 39/44] START C=5, class_weight=None, penalty=l1.......................
# [CV 3/10; 39/44] END C=5, class_weight=None, penalty=l1;, score=0.939 total time=   0.7s
# [CV 4/10; 40/44] START C=5, class_weight=None, penalty=l2.......................
# [CV 4/10; 40/44] END C=5, class_weight=None, penalty=l2;, score=0.958 total time=   0.2s
# [CV 2/10; 41/44] START C=10, class_weight=balanced, penalty=l1..................
# [CV 2/10; 41/44] END C=10, class_weight=balanced, penalty=l1;, score=0.945 total time=   1.8s
# [CV 9/10; 41/44] START C=10, class_weight=balanced, penalty=l1..................
# [CV 9/10; 41/44] END C=10, class_weight=balanced, penalty=l1;, score=0.966 total time=   2.0s
# [CV 5/10; 43/44] START C=10, class_weight=None, penalty=l1......................
# [CV 5/10; 43/44] END C=10, class_weight=None, penalty=l1;, score=0.938 total time=   0.4s
# [CV 9/10; 43/44] START C=10, class_weight=None, penalty=l1......................
# [CV 9/10; 43/44] END C=10, class_weight=None, penalty=l1;, score=0.966 total time=   0.4s
# [CV 4/10; 44/44] START C=10, class_weight=None, penalty=l2......................
# [CV 4/10; 44/44] END C=10, class_weight=None, penalty=l2;, score=0.957 total time=   0.1s
# [CV 9/10; 44/44] START C=10, class_weight=None, penalty=l2......................
# [CV 9/10; 44/44] END C=10, class_weight=None, penalty=l2;, score=0.966 total time=   0.2s
# [CV 8/10; 1/40] START C=0.01, class_weight=balanced, penalty=l1.................
# [CV 8/10; 1/40] END C=0.01, class_weight=balanced, penalty=l1;, score=0.954 total time=   0.1s
# [CV 3/10; 2/40] START C=0.01, class_weight=balanced, penalty=l2.................
# [CV 3/10; 2/40] END C=0.01, class_weight=balanced, penalty=l2;, score=0.953 total time=   0.1s
# [CV 5/10; 3/40] START C=0.01, class_weight=None, penalty=l1.....................
# [CV 5/10; 3/40] END C=0.01, class_weight=None, penalty=l1;, score=0.943 total time=   0.1s
# [CV 6/10; 3/40] START C=0.01, class_weight=None, penalty=l1.....................
# [CV 6/10; 3/40] END C=0.01, class_weight=None, penalty=l1;, score=0.923 total time=   0.1s
# [CV 1/10; 5/40] START C=0.02, class_weight=balanced, penalty=l1.................
# [CV 1/10; 5/40] END C=0.02, class_weight=balanced, penalty=l1;, score=0.958 total time=   0.2s
# [CV 2/10; 5/40] START C=0.02, class_weight=balanced, penalty=l1.................
# [CV 2/10; 5/40] END C=0.02, class_weight=balanced, penalty=l1;, score=0.949 total time=   0.1s
# [CV 9/10; 6/40] START C=0.02, class_weight=balanced, penalty=l2.................
# [CV 9/10; 6/40] END C=0.02, class_weight=balanced, penalty=l2;, score=0.965 total time=   0.1s
# [CV 10/10; 6/40] START C=0.02, class_weight=balanced, penalty=l2................
# [CV 10/10; 6/40] END C=0.02, class_weight=balanced, penalty=l2;, score=0.954 total time=   0.1s
# [CV 1/10; 9/40] START C=0.3, class_weight=balanced, penalty=l1..................
# [CV 1/10; 9/40] END C=0.3, class_weight=balanced, penalty=l1;, score=0.958 total time=   3.6s
# [CV 2/10; 9/40] START C=0.3, class_weight=balanced, penalty=l1..................
# [CV 2/10; 9/40] END C=0.3, class_weight=balanced, penalty=l1;, score=0.946 total time=   2.0s
# [CV 4/10; 20/40] START C=0.05, class_weight=None, penalty=l2....................
# [CV 4/10; 20/40] END C=0.05, class_weight=None, penalty=l2;, score=0.957 total time=   0.1s
# [CV 9/10; 20/40] START C=0.05, class_weight=None, penalty=l2....................
# [CV 9/10; 20/40] END C=0.05, class_weight=None, penalty=l2;, score=0.965 total time=   0.1s
# [CV 8/10; 21/40] START C=0.06, class_weight=balanced, penalty=l1................
# [CV 8/10; 21/40] END C=0.06, class_weight=balanced, penalty=l1;, score=0.955 total time=   0.5s
# [CV 6/10; 22/40] START C=0.06, class_weight=balanced, penalty=l2................
# [CV 6/10; 22/40] END C=0.06, class_weight=balanced, penalty=l2;, score=0.942 total time=   0.1s
# [CV 2/10; 23/40] START C=0.06, class_weight=None, penalty=l1....................
# [CV 2/10; 23/40] END C=0.06, class_weight=None, penalty=l1;, score=0.942 total time=   0.1s
# [CV 1/10; 24/40] START C=0.06, class_weight=None, penalty=l2....................
# [CV 1/10; 24/40] END C=0.06, class_weight=None, penalty=l2;, score=0.949 total time=   0.1s
# [CV 6/10; 24/40] START C=0.06, class_weight=None, penalty=l2....................
# [CV 6/10; 24/40] END C=0.06, class_weight=None, penalty=l2;, score=0.926 total time=   0.1s
# [CV 4/10; 25/40] START C=0.07, class_weight=balanced, penalty=l1................
# [CV 4/10; 25/40] END C=0.07, class_weight=balanced, penalty=l1;, score=0.963 total time=   0.7s
# [CV 9/10; 26/40] START C=0.07, class_weight=balanced, penalty=l2................
# [CV 9/10; 26/40] END C=0.07, class_weight=balanced, penalty=l2;, score=0.965 total time=   0.2s
# [CV 6/10; 27/40] START C=0.07, class_weight=None, penalty=l1....................
# [CV 6/10; 27/40] END C=0.07, class_weight=None, penalty=l1;, score=0.925 total time=   0.2s
# [CV 5/10; 28/40] START C=0.07, class_weight=None, penalty=l2....................
# [CV 5/10; 28/40] END C=0.07, class_weight=None, penalty=l2;, score=0.941 total time=   0.1s
# [CV 4/10; 29/40] START C=0.08, class_weight=balanced, penalty=l1................
# [CV 4/10; 29/40] END C=0.08, class_weight=balanced, penalty=l1;, score=0.963 total time=   0.6s
# [CV 4/10; 30/40] START C=0.08, class_weight=balanced, penalty=l2................
# [CV 4/10; 30/40] END C=0.08, class_weight=balanced, penalty=l2;, score=0.965 total time=   0.2s
# [CV 10/10; 30/40] START C=0.08, class_weight=balanced, penalty=l2...............
# [CV 10/10; 30/40] END C=0.08, class_weight=balanced, penalty=l2;, score=0.953 total time=   0.2s
# [CV 1/10; 32/40] START C=0.08, class_weight=None, penalty=l2....................
# [CV 1/10; 32/40] END C=0.08, class_weight=None, penalty=l2;, score=0.949 total time=   0.1s
# [CV 6/10; 32/40] START C=0.08, class_weight=None, penalty=l2....................
# [CV 6/10; 32/40] END C=0.08, class_weight=None, penalty=l2;, score=0.926 total time=   0.1s
# [CV 2/10; 33/40] START C=0.09, class_weight=balanced, penalty=l1................
# [CV 2/10; 33/40] END C=0.09, class_weight=balanced, penalty=l1;, score=0.947 total time=   0.8s
# [CV 4/10; 34/40] START C=0.09, class_weight=balanced, penalty=l2................
# [CV 4/10; 34/40] END C=0.09, class_weight=balanced, penalty=l2;, score=0.966 total time=   0.2s
# [CV 1/10; 35/40] START C=0.09, class_weight=None, penalty=l1....................
# [CV 1/10; 35/40] END C=0.09, class_weight=None, penalty=l1;, score=0.950 total time=   0.1s
# [CV 8/10; 35/40] START C=0.09, class_weight=None, penalty=l1....................
# [CV 8/10; 35/40] END C=0.09, class_weight=None, penalty=l1;, score=0.935 total time=   0.5s
# [CV 5/10; 37/40] START C=0.1, class_weight=balanced, penalty=l1.................
# [CV 5/10; 37/40] END C=0.1, class_weight=balanced, penalty=l1;, score=0.951 total time=   1.0s
# [CV 10/10; 38/40] START C=0.1, class_weight=balanced, penalty=l2................
# [CV 10/10; 38/40] END C=0.1, class_weight=balanced, penalty=l2;, score=0.953 total time=   0.2s
# [CV 9/10; 39/40] START C=0.1, class_weight=None, penalty=l1.....................
# [CV 9/10; 39/40] END C=0.1, class_weight=None, penalty=l1;, score=0.965 total time=   0.1s
# [CV 10/10; 39/40] START C=0.1, class_weight=None, penalty=l1....................
# [CV 10/10; 39/40] END C=0.1, class_weight=None, penalty=l1;, score=0.937 total time=   0.5s

# %% [markdown]
# # Predicting Probabilities

# %%
logr.classes_
# Out:
# array([0, 1])

# %%
logr.predict_proba(x_test)
# Out:
# array([[0.79535026, 0.20464974],
#        [0.72790082, 0.27209918],
#        [0.99446981, 0.00553019],
#        ...,
#        [0.99456396, 0.00543604],
#        [0.964138  , 0.035862  ],
#        [0.89704183, 0.10295817]])

# %%
logr.predict_proba(x_test)[:,1]
# Out:
# array([0.20464974, 0.27209918, 0.00553019, ..., 0.00543604, 0.035862  ,
#        0.10295817])

# %%
test_score=logr.predict_proba(x_test)[:,1]

# %% [markdown]
# # Find cutoff for hardclass prediction

# %%
train_score=logr.predict_proba(x_train)[:,1]

# %%
real=y_train

# %%
cutoffs=np.linspace(0.001,0.999,999)

# %%
KS_all=[]

for cutoff in cutoffs:
    predicted=(train_score>cutoff).astype(int)

    TP=((predicted==1) & (real==1)).sum()
    TN=((predicted==0) & (real==0)).sum()
    FP=((predicted==1) & (real==0)).sum()
    FN=((predicted==0) & (real==1)).sum()

    P=TP+FN
    N=TN+FP

    KS=(TP/P)-(FP/N)
    
    KS_all.append(KS)

# %%
mycutoff=cutoffs[KS_all==max(KS_all)]

# %%
mycutoff

# if you get multiple values here , then simply go with the first one
# Out:
# array([0.524])

# %%
test_classes=(test_score>mycutoff).astype(int)

# %%
test_classes
# Out:
# array([0, 0, 0, ..., 0, 0, 0])
